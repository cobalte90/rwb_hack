# %% [markdown]
# # WildHack EDA
# ??????????? ??????? ??? ???????? ??????? train/test ? ??????? ??????????.

# %%
import pandas as pd
train = pd.read_parquet('../info_for_codex/data/train.parquet')
test = pd.read_parquet('../info_for_codex/data/test.parquet')
print(train.shape, test.shape)
print(train.columns.tolist())
print(test.columns.tolist())
train.groupby('route_id')['office_from_id'].nunique().describe()
